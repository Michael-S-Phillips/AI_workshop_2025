# %% [markdown]
# # Workshop Outline
#
# ## 📋 Overview Presentation
# **🕘 9:30am - 10:30am**
#
# ---
#
# ## ⚙️ Content & Setup
# **🕙 10:30am - 11:00am**
#
# ### Installation Requirements
# - **Conda**
#   - Environment setup and configuration
#   - [Install (mini)Conda](https://www.anaconda.com/docs/getting-started/miniconda/install)
# - **Code Editor**
#   - [VS Code installation](https://code.visualstudio.com/download)
#   - GitHub Copilot integration
# - **LM Studio**
#   - Local LLM deployment tool
#   - [Install Link](https://lmstudio.ai)
#
# ### Downloads & Resources
# - **GitHub Repository**
#   - Workshop notebooks and sample data
#   - [repo link](https://github.com/Michael-S-Phillips/AI_workshop_2025)
# - **Zenodo Data**
#   - [Labeled image datasets](https://zenodo.org/records/7384288) for semantic segmentation tasks
#
# ---
#
# ## 🤖 Large Language Models (LLMs)
# **🕚 11:00am - 12:30pm**
#
# ### Session Components
# - **Theory Foundation**
#   - Visual demonstration: [Interactive LLM Visualization](https://bbycroft.net/llm)
# - **Hands-on Tools**
#   - GitHub Copilot integration
#   - LM Studio local deployment
#   - [Claude Desktop App](https://www.anthropic.com)
#
# ---
#
# ## 🍽️ Lunch Break
# **🕐 12:30pm - 1:30pm**
#
# ---
#
# ## 📊 Machine Learning (ML)
# **🕐 1:30pm - 2:30pm**
#
# ### Core Topics
# - Basic classification algorithms
# - Deep dive into specific methods *(time and interest permitting)*
#
# ---
#
# ## 🧠 Deep Learning (DL)
# **🕑 2:30pm - 5:00pm**
#
# ### Advanced Topics
# - **Multi-Layer Perceptrons (MLPs)**
#   - Architecture and implementation
# - **Vision Embeddings**
#   - Feature extraction and representation learning
# - **Semantic Segmentation**
#   - Practical implementation
#   - Weights & Biases (WandB) integration *(if time allows)*
#
# ---
#
# *Total Duration: 7.5 hours (including 1-hour lunch break)*
